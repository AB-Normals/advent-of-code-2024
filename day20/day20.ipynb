# %% [markdown]
# # --- Day 20: Race Condition ---

# %%
# --- Part One ---

from typing import List, Dict

filename = "index.txt"
filename = "test.txt" # decomment to test

class Racemap:

    def __init__(self, filename: str):
        self.width :int = 0
        self.height :int = 0
        self.racemap = self.load(filename)

    def load(self, filename: str) -> List[List[str]]:
        with open(filename, 'rt') as file:
            return [list(c) for c in [l.strip() for l in file]]

    def map(self):
        # map racemap caracteristics
        self.width = len(self.racemap[0])
        self.height = len(self.racemap)

    def __str__(self):
        retstr = ""
        for row in self.racemap:
            retstr += "".join(row) + "\n"
        return retstr





# ---- main ----
racemap = Racemap(filename)

print(racemap)


res1 = 0

print(f"The solution for part 1 is: {res1}")
# Out:
# ###############
# #...#...#.....#
# #.#.#.#.#.###.#
# #S#...#.#.#...#
# #######.#.#.###
# #######.#.#...#
# #######.#.###.#
# ###..E#...#...#
# ###.#######.###
# #...###...#...#
# #.#####.#.###.#
# #.#...#.#.#...#
# #.#.#.#.#.#.###
# #...#...#...###
# ###############
#
# The solution for part 1 is: 0
