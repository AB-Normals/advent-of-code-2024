# %% [markdown]
# # --- Day 20: Race Condition ---

# %%
# --- Part One ---

from typing import List, Dict, Tuple
from collections import deque, defaultdict

filename = "input.txt"
#filename = "test.txt" # decomment to test

class Racemap:

    def __init__(self, filename: str):
        self.size : Tuple[int, int] = tuple()
        self.height :int = 0
        self.start : Tuple[int, int] = None
        self.end : Tuple[int, int] = None
        self.cheats: List[Tuple[int,int]] = []
        self.path: Dict[Tuple[int,int]: int] = {}
        self.racemap = self.load(filename)
        self._map()

    def load(self, filename: str) -> List[List[str]]:
        with open(filename, 'rt') as file:
            return [list(c) for c in [l.strip() for l in file]]

    def _can_cheat(self, pos: Tuple[int, int]):
        """ 
        Check if that wall can be cheated (open a passage): 'pos' must be a wall (#) position) 
        """
        x , y = pos
        if x < 1 or x >= self.size[0]-1 or y < 0 or y >= self.size[1]-1:
            return False
        if ((self.racemap[y][x+1] in ['.', 'S', 'E'] and self.racemap[y][x-1] in ['.', 'S', 'E']) or 
            (self.racemap[y+1][x] in ['.', 'S', 'E'] and self.racemap[y-1][x] in ['.', 'S', 'E'])):
            return True
        return False

    def _map(self):
        # map racemap caracteristics : size and possible cheats
        self.size = (len(self.racemap[0]),len(self.racemap))
        for y, row in enumerate(self.racemap):
            for x, cell in enumerate(row):
                if cell == "#": 
                    # check if it is a possible cheat
                    if self._can_cheat((x,y)):
                        self.cheats.append((x,y))                    
                    continue
                if cell == "S":
                    self.start = (x,y)
                if cell == "E":
                    self.end = (x,y)

    def bsf_path_find(self, cheat = None):
        """
        Breadth-First Search : find minimum path (useable if all steps have same cost)
        """
        moves = [(-1, 0), (1 , 0), (0, -1),(0, 1)]
        # BFS queue : (pos(x,y) , picoseconds, [(pos(x,y), picoseconds)])
        queue = deque([(self.start, 0, [(self.start, 0)])])
        visited= set() # store position and step to reach that position 
        cheated = False

        while queue:
            (x,y), ps, path = queue.popleft()
            # If 'end' position is reached, return the path
            if (x, y) == self.end:
                if not cheat: self.path = {k: v for k, v in path}
                return self.path
            # Mark cell as visited
            visited.add((x, y)) 
            # Explore the neighbors
            for dx, dy in moves:
                nx, ny = x +dx, y + dy
                if (nx, ny) == cheat:
                    cheated = True
                    queue.append(((nx, ny), ps +1, path + [((nx, ny), ps+1)]))
                # Check if neighbor is valid and not visited
                if 0 <= nx < self.size[0] and 0 <= ny < self.size[1] and self.racemap[ny][nx] in [".","E"] and (nx, ny) not in visited:
                    if cheated :
                        if self.path[(nx,ny)]>ps+1:
                            # print (f"path[({nx, ny})] = {self.path[nx, ny]} > {ps+1}")
                            return (cheat, self.path[(nx,ny)] - ps -1)
                    queue.append(((nx, ny), ps +1, path + [((nx, ny), ps+1)]))
        # If path not found
        return None

    def all_cheats_savings(self):
        if not self.path:
            self.self.bsf_path_find()
        savings = []
        for cheat in self.cheats:
            s = self.bsf_path_find(cheat)
            # print(s)
            savings.append(s)
        return savings

    def __str__(self):
        retstr = ""
        for row in self.racemap:
            retstr += "".join(row) + "\n"
        return retstr



# ---- main ----
racemap = Racemap(filename)

# print(racemap)
cheats = racemap.cheats
print(f"Found {len(cheats)} possible cheats")
path = racemap.bsf_path_find()
normal_speed = len(path)-1
print (f"Normal race (no cheat) is {len(path)-1} picoseconds.")
cheated_speeds: List[int] = []
# print (path)

# for x, y in cheats:
#     # apply the cheat
#     racemap.racemap[y][x] = '.'
#     cheated_speeds.append(len(racemap.bsf_path_find())-1)
#     racemap.racemap[y][x] = '#'

savings = racemap.all_cheats_savings()

print(savings)

#res1 = len([s for s in cheated_speeds if normal_speed - s >= 100])
res1 = len([(c, s) for c, s in savings if s >= 100])
print(f"The solution for part 1 is: {res1}")
# Out:
# [((4, 1), 176), ((18, 1), 4), ((22, 1), 4), ((26, 1), 8), ((30, 1), 128), ((40, 1), 292), ((50, 1), 532), ((66, 1), 28), ((72, 1), 384), ((82, 1), 24), ((86, 1), 8), ((100, 1), 252), ((104, 1), 4), ((136, 1), 472), ((2, 2), 2), ((4, 2), 174), ((6, 2), 2), ((7, 2), 4), ((8, 2), 6), ((9, 2), 8), ((11, 2), 16), ((12, 2), 18), ((13, 2), 20), ((14, 2), 22), ((15, 2), 24), ((18, 2), 2), ((20, 2), 2), ((22, 2), 2), ((24, 2), 2), ((26, 2), 6), ((28, 2), 2), ((30, 2), 126), ((32, 2), 2), ((38, 2), 2), ((40, 2), 290), ((42, 2), 2), ((43, 2), 4), ((44, 2), 6), ((45, 2), 8), ((46, 2), 10), ((47, 2), 12), ((50, 2), 530), ((53, 2), 8), ((54, 2), 10), ((55, 2), 12), ((57, 2), 16), ((58, 2), 14), ((59, 2), 12), ((60, 2), 10), ((61, 2), 8), ((62, 2), 6), ((63, 2), 4), ((64, 2), 2), ((66, 2), 26), ((69, 2), 4), ((70, 2), 2), ((72, 2), 382), ((74, 2), 2), ((75, 2), 4), ((76, 2), 6), ((77, 2), 8), ((78, 2), 10), ((79, 2), 12), ((82, 2), 22), ((84, 2), 2), ((86, 2), 6), ((89, 2), 28), ((90, 2), 26), ((91
# ...
